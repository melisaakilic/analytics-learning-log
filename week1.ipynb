# %%
import pandas as pd
print("pandas version:", pd.__version__)
print("hello NovaPay")
# Out:
# pandas version: 2.3.3
# hello NovaPay

# %%
#şuan commit için bir alıştırma yapıyorum 
to_do_list="dil çalışma","baklava","duş alma","markete gitme","pdfleri kontrol et ","akşam yemeğine git"
print(to_do_list)
# Out:
# ('dil çalışma', 'baklava', 'duş alma', 'markete gitme', 'pdfleri kontrol et ', 'akşam yemeğine git')

# %%
data = {"transaction": [100, 250, 90, 4000, 75],
        "country": ["NL", "NL", "DE", "NL", "BE"]}
df = pd.DataFrame(data)
df.groupby("country")["transaction"].sum()
# Out:
# country
# BE      75
# DE      90
# NL    4350
# Name: transaction, dtype: int64

# %%
#from learntools.core import binder; binder.bind(globals())
#from learntools.python.ex1 import *
#print("Setup complete! You're ready to start question 0.")
#BU KÜTÜPHANE OLMADIĞI İÇİN BENDE ÇALIŞMADI KAGGLE A AİT BİR KÜTÜPHANE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from learntools.core import binder; binder.bind(globals())
#       2 from learntools.python.ex1 import *
#       3 print("Setup complete! You're ready to start question 0.")
#
# ModuleNotFoundError: No module named 'learntools'

# %%
#create a variable called color in the cell 
my_colors="red","black","white","blue"
print(my_colors)
# Out:
# ('red', 'black', 'white', 'blue')

# %%
a = [1, 2, 3]
b = [3, 2, 1]


tmp = a
a = b
b = tmp

a, b = b, a

# %%
print(a)
print(b)
# Out:
# [1, 2, 3]
# [3, 2, 1]

# %%
#Alice, Bob and Carol have agreed to pool their Halloween candy and split it evenly among themselves. For the sake of their friendship, any candies left over will be smashed. For example, if they collectively bring home 91 candies, they'll take 30 each and smash 1.

#Write an arithmetic expression below to calculate how many candies they must smash for a given haul.

alice_candies = 121
bob_candies = 77
carol_candies = 109
A= alice_candies + bob_candies +carol_candies
print(A)
print(A%3)
# Out:
# 307
# 1

# %%
def mult_by_five(x):
    return 5 * x

#Görevi: gelen sayıyı 5 ile çarpıp geri döndürmek.

#Örnek: mult_by_five(2) → 10.



def call(fn, arg):
    """Call fn on arg"""
    return fn(arg)

def squared_call(fn, arg):
    """Call fn on the result of calling fn on arg"""
    return fn(fn(arg))
